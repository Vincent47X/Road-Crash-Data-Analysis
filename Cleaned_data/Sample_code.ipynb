# %%
import pandas as pd

df = pd.read_csv("Crash_Report_Cleaned.csv", low_memory=False)

# %%
sample_df = df.sample(10000, random_state=42)

sample_df.to_csv("Cleaned_Crash_Report_Sample.csv", index=False)
